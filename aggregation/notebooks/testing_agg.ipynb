# %%
import pytorch_lightning as pl
from trainAgg import OnexOneAggregationModule
from util import my_collate
import util
import data_factory
import numpy as np
import torch
from config import cfg
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy import stats

# %%
this_dataset = util.make_dataset(mode = 'train')
# Out:
# Reading GeoDataFrame...
# Done
# Loading all values...

# %%
for sample in this_dataset:
    mask_array = sample['parcel_masks']
    fig, axs = plt.subplots(1,len(masks_array), figsize = (400,20))
    fig
    
    for i,mask in enumerate(mask_array):
        axs[i].imshow(mask.reshape(302,302))
    plt.figure(1)
    plt.imshow(np.array(sample['image'].permute(1,2,0)))

    break
