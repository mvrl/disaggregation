# %%
import pytorch_lightning as pl
from trainAgg import OnexOneAggregationModule
from util import my_collate
import util
import data_factory
import numpy as np
import torch
from config import cfg
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy import stats

# %%
this_dataset = util.make_dataset(mode = 'train', uniform=True)
# Out:
# Reading GeoDataFrame...
# Done
# Loading all values...

# %%
for sample in this_dataset:
    fig, axs = plt.subplots(1,3, figsize = (50,20))

    axs[0].imshow(sample['image'].permute(1,2,0))
    axs[2].imshow(sample['uniform_value_map'])
    axs[1].imshow(sample['total_parcel_mask'])
    #plt.imshow(np.array(sample['image'].permute(1,2,0)))

    print()

    break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
